# %%
import os
import re
import fnmatch
import pandas as pd

path = "F:/Data/Cinémathèque"  # F:\Data\Cinémathèque
pattern = "*.mkv"

# %%
def list_lstrip(list_to_clean):
    list_cleaned = []
    for string in list_to_clean:
        list_cleaned.append(string.lstrip())
        
    return list_cleaned

# %%
def get_information(file_name):
    regex = re.findall('(\(\d\d\d\d\))', file_name)  # Find the date
    try:
        name, end = file_name.split(regex[0])  # Get name and director
    except Exception as e:
        print(e)
        print(file_name + '\n')
        return {
            'name': file_name,
            'date': None,
            'directors': [],  # Get Directors list,
            'details': []
        }    

    name = name[:-1]  # Supress useless character for the name

    end = end.split(' [')
    if len(end) < 2:
        director = end[0][1:]  # Supress useless character for the director
        detail = []
    else:
        director = end[0]
        detail = end[1][:-1]  # Supress useless character for the details
        detail = detail.split('][')  # Get details list
    
    # Save the date
    return {
        'name': name.lstrip(),
        'date': regex[0].replace('(', '').replace(')', ''),
        'directors': list_lstrip(director.split(', ')),  # Get Directors list,
        'details': list_lstrip(detail)
    }

# %%
def get_mkv_list(path="D:/Cinémathèque/", pattern="*.mkv"):
    file_list = []
    for root, dirs, files in os.walk(path):
        if root == path:  # To prevent subfolder analyze
            for file in files:
                if fnmatch.fnmatch(file, pattern):  # to get only with ".mkv" extension
                    file_list.append({'path': path, 'file': file[:-len(pattern)+1], 'extension': pattern[1:]})
    return pd.DataFrame(file_list)

mkv_list = get_mkv_list(path=path, pattern=pattern)
mkv_list
# Out:
#                       path                                               file  \
# 0     F:/Data/Cinémathèque              (500) Jours Ensemble (2009) Marc Webb
# 1     F:/Data/Cinémathèque                   1001 pattes (1998) John Lasseter
# 2     F:/Data/Cinémathèque            12 Hommes en Colere (1957) Sidney Lumet
# 3     F:/Data/Cinémathèque              12 Years a Slave (2013) Steve McQueen
# 4     F:/Data/Cinémathèque    120 Battements par Minute (2017) Robin Campillo
# ...                    ...                                                ...
# 1205  F:/Data/Cinémathèque                     Zombie (1978) George A. Romero
# 1206  F:/Data/Cinémathèque  Zootopia (2016) Rich Moore, Byron Howard, Jare...
# 1207  F:/Data/Cinémathèque   À Bord du Darjeeling Limited (2007) Wes Anderson
# 1208  F:/Data/Cinémathèque           À bout de souffle (1960) Jean-Luc Godard
# 1209  F:/Data/Cinémathèque                    À toute épreuve (1992) John Woo
#
#      extension
# 0         .mkv
# 1         .mkv
# 2         .mkv
# 3         .mkv
# 4         .mkv
# ...        ...
# 1205      .mkv
# 1206      .mkv
# 1207      .mkv
# 1208      .mkv
# 1209      .mkv
#
# [1210 rows x 3 columns]

# %%
data = []

for idx, row in mkv_list.iterrows():
    file_name = row.file

    data.append(get_information(file_name))
    
    
files_details = pd.DataFrame(data)
files_details
# Out:
# list index out of range
# American History X Deleted Scenes
#
# list index out of range
# Conte des chrysanthemes tardifs 1939 VOSTF DVDRIP HEVC AZAZE
#
# list index out of range
# Like Someone in Love (Abbas Kiarostami) 2012
#
# list index out of range
# MACROSS PLUS - 01 [1080p]
#
# list index out of range
# MACROSS PLUS - 02 [1080p]
#
# list index out of range
# MACROSS PLUS - 03 [1080p]
#
# list index out of range
# MACROSS PLUS - 04 [1080p]
#
# list index out of range
# Pixar Intro Old
#                               name  date  \
# 0             (500) Jours Ensemble  2009
# 1                      1001 pattes  1998
# 2              12 Hommes en Colere  1957
# 3                 12 Years a Slave  2013
# 4        120 Battements par Minute  2017
# ...                            ...   ...
# 1205                        Zombie  1978
# 1206                      Zootopia  2016
# 1207  À Bord du Darjeeling Limited  2007
# 1208             À bout de souffle  1960
# 1209               À toute épreuve  1992
#
#                                    directors details
# 0                                [Marc Webb]      []
# 1                            [John Lasseter]      []
# 2                             [Sidney Lumet]      []
# 3                            [Steve McQueen]      []
# 4                           [Robin Campillo]      []
# ...                                      ...     ...
# 1205                      [George A. Romero]      []
# 1206  [Rich Moore, Byron Howard, Jared Bush]      []
# 1207                          [Wes Anderson]      []
# 1208                       [Jean-Luc Godard]      []
# 1209                              [John Woo]      []
#
# [1210 rows x 4 columns]

# %%
mkv_detail = pd.concat([mkv_list, files_details], axis=1)
mkv_detail
# Out:
#                       path                                               file  \
# 0     F:/Data/Cinémathèque              (500) Jours Ensemble (2009) Marc Webb
# 1     F:/Data/Cinémathèque                   1001 pattes (1998) John Lasseter
# 2     F:/Data/Cinémathèque            12 Hommes en Colere (1957) Sidney Lumet
# 3     F:/Data/Cinémathèque              12 Years a Slave (2013) Steve McQueen
# 4     F:/Data/Cinémathèque    120 Battements par Minute (2017) Robin Campillo
# ...                    ...                                                ...
# 1205  F:/Data/Cinémathèque                     Zombie (1978) George A. Romero
# 1206  F:/Data/Cinémathèque  Zootopia (2016) Rich Moore, Byron Howard, Jare...
# 1207  F:/Data/Cinémathèque   À Bord du Darjeeling Limited (2007) Wes Anderson
# 1208  F:/Data/Cinémathèque           À bout de souffle (1960) Jean-Luc Godard
# 1209  F:/Data/Cinémathèque                    À toute épreuve (1992) John Woo
#
#      extension                          name  date  \
# 0         .mkv          (500) Jours Ensemble  2009
# 1         .mkv                   1001 pattes  1998
# 2         .mkv           12 Hommes en Colere  1957
# 3         .mkv              12 Years a Slave  2013
# 4         .mkv     120 Battements par Minute  2017
# ...        ...                           ...   ...
# 1205      .mkv                        Zombie  1978
# 1206      .mkv                      Zootopia  2016
# 1207      .mkv  À Bord du Darjeeling Limited  2007
# 1208      .mkv             À bout de souffle  1960
# 1209      .mkv               À toute épreuve  1992
#
#                                    directors details
# 0                                [Marc Webb]      []
# 1                            [John Lasseter]      []
# 2                             [Sidney Lumet]      []
# 3                            [Steve McQueen]      []
# 4                           [Robin Campillo]      []
# ...                                      ...     ...
# 1205                      [George A. Romero]      []
# 1206  [Rich Moore, Byron Howard, Jared Bush]      []
# 1207                          [Wes Anderson]      []
# 1208                       [Jean-Luc Godard]      []
# 1209                              [John Woo]      []
#
# [1210 rows x 7 columns]

# %%
files_details.to_csv('D:/Cinémathèque/movie_list.csv', header=True, index=False, sep=';')

# %% [markdown]
# # Update Movie details

# %% [markdown]
# # Some stat about the library

# %%
import statistics

statistics.mean(list(map(int, list(filter(None, files_details.date.to_list())))))
# Out:
# 1995.8431876606685

# %%
res = files_details.directors.apply(tuple).value_counts()
pd.DataFrame(res).head(20)
# Out:
#                          directors
# (Steven Spielberg,)             19
# (Hayao Miyazaki,)               11
# (Quentin Tarantino,)            10
# (John Carpenter,)                9
# (Stanley Kubrick,)               9
# (Martin Scorsese,)               8
# (Clint Eastwood,)                8
# (David Cronenberg,)              8
# (Christopher Nolan,)             8
# (David Fincher,)                 8
# ()                               7
# (Akira Kurosawa,)                7
# (Paul Thomas Anderson,)          7
# (Tsui Hark,)                     7
# (Robert Zemeckis,)               7
# (David Lynch,)                   7
# (Denis Villeneuve,)              6
# (Wes Anderson,)                  6
# (Nicolas Winding Refn,)          6
# (Ridley Scott,)                  6

# %% [markdown]
# # Update files metadata
#
# Bash command example :
# ```bash
# mkvpropedit movie.mkv --edit info --set "title=The movie" --edit track:a1 --set language=fre --edit track:a2 --set language=ita
# ```
#
# Python example :
# ```python
# 'mkvpropedit ' + file_name + file_ext + ' --tags all:'  # Remove all tags
# 'mkvpropedit ' + file_name + file_ext + ' --edit info --set ' +   # Edit file info
#     '"title=' + file_name + '" ' +
#     '"year=' + file_year + '" ' +
#     '"directors=' + file_directors + '"' +
#     (' "tags=' + file_tag + '" ' if file_tag)
# ```
#
# Bash command :
# ```bash
# .\mkvpropedit "D:\Cinémathèque\L'illusionniste (2010) Sylvain Chomet.mkv" --edit info --set "title=L'illusionniste" --add "year=2010"
# .\mkvpropedit "D:\Cinémathèque\L'illusionniste (2010) Sylvain Chomet.mkv" --list-property-names
# ```

# %% [markdown]
# .\mkvpropedit "D:\Cinémathèque\L'illusionniste (2010) Sylvain Chomet.mkv" --tags

# %%
for idx, row in mkv_detail.iterrows():
    print('.\mkvpropedit "' + str(row.path + '/' + row.file + row.extension) +  '" --tags all:')
    print('.\mkvpropedit "' + str(row.path + '/' + row.file + row.extension) +  '" --edit info --set "title=' + str(row['name']) + '"\n')
    #print('.\mkvpropedit "' + str(row.path + '/' + row.file + row.extension) +  '" --edit info --set "comments=' + str({'date': row.date, 'directors': row.directors}) + '"\n')
# Out:
# .\mkvpropedit "F:/Data/Cinémathèque/(500) Jours Ensemble (2009) Marc Webb.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/(500) Jours Ensemble (2009) Marc Webb.mkv" --edit info --set "title=(500) Jours Ensemble"
#
# .\mkvpropedit "F:/Data/Cinémathèque/1001 pattes (1998) John Lasseter.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/1001 pattes (1998) John Lasseter.mkv" --edit info --set "title=1001 pattes"
#
# .\mkvpropedit "F:/Data/Cinémathèque/12 Hommes en Colere (1957) Sidney Lumet.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/12 Hommes en Colere (1957) Sidney Lumet.mkv" --edit info --set "title=12 Hommes en Colere"
#
# .\mkvpropedit "F:/Data/Cinémathèque/12 Years a Slave (2013) Steve McQueen.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/12 Years a Slave (2013) Steve McQueen.mkv" --edit info --set "title=12 Years a Slave"
#
# .\mkvpropedit "F:/Data/Cinémathèque/120 Battements par Minute (2017) Robin Campillo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/120 Battements par Minute (2017) Robin Campillo.mkv" --edit info --set "title=120 Battements par Minute"
#
# .\mkvpropedit "F:/Data/Cinémathèque/127 Heures (2010) Danny Boyle.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/127 Heures (2010) Danny Boyle.mkv" --edit info --set "title=127 Heures"
#
# .\mkvpropedit "F:/Data/Cinémathèque/1917 (2019) Sam Mendes.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/1917 (2019) Sam Mendes.mkv" --edit info --set "title=1917"
#
# .\mkvpropedit "F:/Data/Cinémathèque/20 000 (Vingt Mille) Lieues sous les mers (1954) Richard Fleischer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/20 000 (Vingt Mille) Lieues sous les mers (1954) Richard Fleischer.mkv" --edit info --set "title=20 000 (Vingt Mille) Lieues sous les mers"
#
# .\mkvpropedit "F:/Data/Cinémathèque/20.000 Vingt Mille Lieues sous les mers (1954) Richard Fleischer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/20.000 Vingt Mille Lieues sous les mers (1954) Richard Fleischer.mkv" --edit info --set "title=20.000 Vingt Mille Lieues sous les mers"
#
# .\mkvpropedit "F:/Data/Cinémathèque/2001 L'Odyssée de l'Espace (1968) Stanley Kubrick.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/2001 L'Odyssée de l'Espace (1968) Stanley Kubrick.mkv" --edit info --set "title=2001 L'Odyssée de l'Espace"
#
# .\mkvpropedit "F:/Data/Cinémathèque/2046 (2004) Wong Kar-wai.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/2046 (2004) Wong Kar-wai.mkv" --edit info --set "title=2046"
#
# .\mkvpropedit "F:/Data/Cinémathèque/28 Semaines plus tard (2007) Juan Carlos Fresnadillo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/28 Semaines plus tard (2007) Juan Carlos Fresnadillo.mkv" --edit info --set "title=28 Semaines plus tard"
#
# .\mkvpropedit "F:/Data/Cinémathèque/300 (2006) Zack Snyder.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/300 (2006) Zack Snyder.mkv" --edit info --set "title=300"
#
# .\mkvpropedit "F:/Data/Cinémathèque/500 Days of Summer (2009) Marc Webb.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/500 Days of Summer (2009) Marc Webb.mkv" --edit info --set "title=500 Days of Summer"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A Bittersweet Life (2005) Kim Jee-wom.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A Bittersweet Life (2005) Kim Jee-wom.mkv" --edit info --set "title=A Bittersweet Life"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A Bout de Course (1988) Sidney Lumet.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A Bout de Course (1988) Sidney Lumet.mkv" --edit info --set "title=A Bout de Course"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A Dangerous Method (2011) David Cronenberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A Dangerous Method (2011) David Cronenberg.mkv" --edit info --set "title=A Dangerous Method"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A Ghost Story (2017) David Lowery.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A Ghost Story (2017) David Lowery.mkv" --edit info --set "title=A Ghost Story"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A History of Violence (2005) David Cronenberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A History of Violence (2005) David Cronenberg.mkv" --edit info --set "title=A History of Violence"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A La Recherche Du Bonheur (2006) Gabriele Muccino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A La Recherche Du Bonheur (2006) Gabriele Muccino.mkv" --edit info --set "title=A La Recherche Du Bonheur"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A Page of Madness (1926) Teinosuke Kinugasa.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A Page of Madness (1926) Teinosuke Kinugasa.mkv" --edit info --set "title=A Page of Madness"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A Touch of Sin (2013) Jia Zhangke.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A Touch of Sin (2013) Jia Zhangke.mkv" --edit info --set "title=A Touch of Sin"
#
# .\mkvpropedit "F:/Data/Cinémathèque/A.I. Intelligence Artificielle (2001) Steven Spielberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/A.I. Intelligence Artificielle (2001) Steven Spielberg.mkv" --edit info --set "title=A.I. Intelligence Artificielle"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Abyss (1989) James Cameron (extended).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Abyss (1989) James Cameron (extended).mkv" --edit info --set "title=Abyss"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Ad Astra (2019) James Gray.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Ad Astra (2019) James Gray.mkv" --edit info --set "title=Ad Astra"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Adieu ma Concubine (1993) Chen Kaige.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Adieu ma Concubine (1993) Chen Kaige.mkv" --edit info --set "title=Adieu ma Concubine"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Adoration (2019) Fabrice Du Welz.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Adoration (2019) Fabrice Du Welz.mkv" --edit info --set "title=Adoration"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Aguirre, la colère de Dieu (1972) Werner Herzog.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Aguirre, la colère de Dieu (1972) Werner Herzog.mkv" --edit info --set "title=Aguirre, la colère de Dieu"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Akira (1988) Katsuhiro Ōtomo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Akira (1988) Katsuhiro Ōtomo.mkv" --edit info --set "title=Akira"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Alabama Monroe (2012) Felix Van Groeningen.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Alabama Monroe (2012) Felix Van Groeningen.mkv" --edit info --set "title=Alabama Monroe"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Alien 3 (1992) David Fincher.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Alien 3 (1992) David Fincher.mkv" --edit info --set "title=Alien 3"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Alien vs. Predator (2004) Paul W. S. Anderson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Alien vs. Predator (2004) Paul W. S. Anderson.mkv" --edit info --set "title=Alien vs. Predator"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Alien, la resurrection (1997) Jean Pierre Jeunet.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Alien, la resurrection (1997) Jean Pierre Jeunet.mkv" --edit info --set "title=Alien, la resurrection"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Alien, Le huitieme passager (1979) Ridley Scott.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Alien, Le huitieme passager (1979) Ridley Scott.mkv" --edit info --set "title=Alien, Le huitieme passager"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Aliens vs. Predator Requiem (2007) Greg Strause, Colin Strause.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Aliens vs. Predator Requiem (2007) Greg Strause, Colin Strause.mkv" --edit info --set "title=Aliens vs. Predator Requiem"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Aliens, le retour (1986) James Cameron.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Aliens, le retour (1986) James Cameron.mkv" --edit info --set "title=Aliens, le retour"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Alita Battle Angel (2019) Robert Rodriguez.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Alita Battle Angel (2019) Robert Rodriguez.mkv" --edit info --set "title=Alita Battle Angel"
#
# .\mkvpropedit "F:/Data/Cinémathèque/All the President's Men (1976) Alan J Pakula.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/All the President's Men (1976) Alan J Pakula.mkv" --edit info --set "title=All the President's Men"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Amadeus (1984) Miloš Forman.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Amadeus (1984) Miloš Forman.mkv" --edit info --set "title=Amadeus"
#
# .\mkvpropedit "F:/Data/Cinémathèque/American Beauty (1999) Sam Mendes.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/American Beauty (1999) Sam Mendes.mkv" --edit info --set "title=American Beauty"
#
# .\mkvpropedit "F:/Data/Cinémathèque/American History X (1998) Tony Kaye.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/American History X (1998) Tony Kaye.mkv" --edit info --set "title=American History X"
#
# .\mkvpropedit "F:/Data/Cinémathèque/American History X Deleted Scenes.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/American History X Deleted Scenes.mkv" --edit info --set "title=American History X Deleted Scenes"
#
# .\mkvpropedit "F:/Data/Cinémathèque/An Elephant Sitting Still (2019) Hu Bo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/An Elephant Sitting Still (2019) Hu Bo.mkv" --edit info --set "title=An Elephant Sitting Still"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Anastasia (1997) Don Bluth, Gary Goldman [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Anastasia (1997) Don Bluth, Gary Goldman [ANIMATION].mkv" --edit info --set "title=Anastasia"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Aniki Mon Frere (2000) Takeshi Kitano.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Aniki Mon Frere (2000) Takeshi Kitano.mkv" --edit info --set "title=Aniki Mon Frere"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Animal Kingdom (2010) David Michôd.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Animal Kingdom (2010) David Michôd.mkv" --edit info --set "title=Animal Kingdom"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Annie Hall (1977) Woody Allen.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Annie Hall (1977) Woody Allen.mkv" --edit info --set "title=Annie Hall"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Antichrist (2009) Lars von Trier.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Antichrist (2009) Lars von Trier.mkv" --edit info --set "title=Antichrist"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Apocalypse Now (1979) Francis Ford Coppola.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Apocalypse Now (1979) Francis Ford Coppola.mkv" --edit info --set "title=Apocalypse Now"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Apocalypto (2006) Mel Gibson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Apocalypto (2006) Mel Gibson.mkv" --edit info --set "title=Apocalypto"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Apollo 13 (1995) ‎Ron Howard.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Apollo 13 (1995) ‎Ron Howard.mkv" --edit info --set "title=Apollo 13"
#
# .\mkvpropedit "F:/Data/Cinémathèque/April Story (1998) Shunji Iwai.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/April Story (1998) Shunji Iwai.mkv" --edit info --set "title=April Story"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Après la tempete (2016) Hirokazu Kore-eda.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Après la tempete (2016) Hirokazu Kore-eda.mkv" --edit info --set "title=Après la tempete"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Argo (2012) Ben Affleck.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Argo (2012) Ben Affleck.mkv" --edit info --set "title=Argo"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Arizona Dream (1992) Emir Kusturica.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Arizona Dream (1992) Emir Kusturica.mkv" --edit info --set "title=Arizona Dream"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Armageddon (1998) Michael Bay.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Armageddon (1998) Michael Bay.mkv" --edit info --set "title=Armageddon"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Arrietty le petit monde des chapardeurs (2010) Hiromasa Yonebayashi.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Arrietty le petit monde des chapardeurs (2010) Hiromasa Yonebayashi.mkv" --edit info --set "title=Arrietty le petit monde des chapardeurs"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Aruvu Rezuru, Kikaijikake no Yōseitachi (2011) Tatsuya Yoshihara.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Aruvu Rezuru, Kikaijikake no Yōseitachi (2011) Tatsuya Yoshihara.mkv" --edit info --set "title=Aruvu Rezuru, Kikaijikake no Yōseitachi"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Assaut (1976) John Carpenter.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Assaut (1976) John Carpenter.mkv" --edit info --set "title=Assaut"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Assurance sur la mort (1944) Billy Wilder.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Assurance sur la mort (1944) Billy Wilder.mkv" --edit info --set "title=Assurance sur la mort"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Asterix et le secret de la potion magique (2018) Alexandre Astier, Louis Clichy [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Asterix et le secret de la potion magique (2018) Alexandre Astier, Louis Clichy [ANIMATION].mkv" --edit info --set "title=Asterix et le secret de la potion magique"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Astérix et Obélix, Mission Cléopâtre (2002) Alain Chabat.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Astérix et Obélix, Mission Cléopâtre (2002) Alain Chabat.mkv" --edit info --set "title=Astérix et Obélix, Mission Cléopâtre"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Astérix, Le Domaine des dieux (2014) Louis Clichy, Alexandre Astier [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Astérix, Le Domaine des dieux (2014) Louis Clichy, Alexandre Astier [ANIMATION].mkv" --edit info --set "title=Astérix, Le Domaine des dieux"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Atlantide, l'empire perdu (2001) Gary Trousdale, Kirk Wise [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Atlantide, l'empire perdu (2001) Gary Trousdale, Kirk Wise [ANIMATION].mkv" --edit info --set "title=Atlantide, l'empire perdu"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Au revoir là-haut (2017) Albert Dupontel.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Au revoir là-haut (2017) Albert Dupontel.mkv" --edit info --set "title=Au revoir là-haut"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Audition (1999) Takashi Miike.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Audition (1999) Takashi Miike.mkv" --edit info --set "title=Audition"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Autant en emporte le vent (1939) Victor Fleming.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Autant en emporte le vent (1939) Victor Fleming.mkv" --edit info --set "title=Autant en emporte le vent"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Avalon (2001) Mamoru Oshii.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Avalon (2001) Mamoru Oshii.mkv" --edit info --set "title=Avalon"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Avatar (2009) James Cameron.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Avatar (2009) James Cameron.mkv" --edit info --set "title=Avatar"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Aya et la Sorciere (2021) Goro Miyazaki.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Aya et la Sorciere (2021) Goro Miyazaki.mkv" --edit info --set "title=Aya et la Sorciere"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Azur et Asmar (2006) Michel Ocelot [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Azur et Asmar (2006) Michel Ocelot [ANIMATION].mkv" --edit info --set "title=Azur et Asmar"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Baby Driver (2017) Edgar Wright.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Baby Driver (2017) Edgar Wright.mkv" --edit info --set "title=Baby Driver"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Bacurau (2019) Kleber Mendonça Filho, Juliano Dornelles.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Bacurau (2019) Kleber Mendonça Filho, Juliano Dornelles.mkv" --edit info --set "title=Bacurau"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Bagdad Café (1988) Percy Adlon [DIRECTOR].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Bagdad Café (1988) Percy Adlon [DIRECTOR].mkv" --edit info --set "title=Bagdad Café"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Balle Perdue (2020) Guillaume Pierret.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Balle Perdue (2020) Guillaume Pierret.mkv" --edit info --set "title=Balle Perdue"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Barberousse (1965) Akira Kurosawa (Akahige).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Barberousse (1965) Akira Kurosawa (Akahige).mkv" --edit info --set "title=Barberousse"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Barry Lyndon (1975) Stanley Kubrick.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Barry Lyndon (1975) Stanley Kubrick.mkv" --edit info --set "title=Barry Lyndon"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Barton Fink (1991) Ethan Coen, Joel Coen.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Barton Fink (1991) Ethan Coen, Joel Coen.mkv" --edit info --set "title=Barton Fink"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Basic Instinct (1992) Paul Verhoeven.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Basic Instinct (1992) Paul Verhoeven.mkv" --edit info --set "title=Basic Instinct"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Batman Begins (2005) Christopher Nolan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Batman Begins (2005) Christopher Nolan.mkv" --edit info --set "title=Batman Begins"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Batman Returns (1992) Tim Burton.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Batman Returns (1992) Tim Burton.mkv" --edit info --set "title=Batman Returns"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Batman v Superman Dawn Of Justice (2016) Zack Snyder [EXTENDED].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Batman v Superman Dawn Of Justice (2016) Zack Snyder [EXTENDED].mkv" --edit info --set "title=Batman v Superman Dawn Of Justice"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Battle Royale (2000) Kinji Fukasaku.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Battle Royale (2000) Kinji Fukasaku.mkv" --edit info --set "title=Battle Royale"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Beetlejuice (1988) Tim Burton.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Beetlejuice (1988) Tim Burton.mkv" --edit info --set "title=Beetlejuice"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Before Sunrise (1995) Richard Linklater.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Before Sunrise (1995) Richard Linklater.mkv" --edit info --set "title=Before Sunrise"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Belle de jour (1967) Luis Buñuel.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Belle de jour (1967) Luis Buñuel.mkv" --edit info --set "title=Belle de jour"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Ben-Hur (1959) William Wyler.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Ben-Hur (1959) William Wyler.mkv" --edit info --set "title=Ben-Hur"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Bienvenue à Zombieland (2009) Ruben Fleischer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Bienvenue à Zombieland (2009) Ruben Fleischer.mkv" --edit info --set "title=Bienvenue à Zombieland"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Big Fish & Begonia (2016) Liang Xuan, Chun Zhang.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Big Fish & Begonia (2016) Liang Xuan, Chun Zhang.mkv" --edit info --set "title=Big Fish & Begonia"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Big Fish (2003) Tim Burton.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Big Fish (2003) Tim Burton.mkv" --edit info --set "title=Big Fish"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Bigamie (1953) Ida Lupino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Bigamie (1953) Ida Lupino.mkv" --edit info --set "title=Bigamie"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Birdman (2014) Alejandro González Iñárritu.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Birdman (2014) Alejandro González Iñárritu.mkv" --edit info --set "title=Birdman"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Black Coal (2014) Diao Yi'nan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Black Coal (2014) Diao Yi'nan.mkv" --edit info --set "title=Black Coal"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Black Snake Moan (2006) Craig Brewer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Black Snake Moan (2006) Craig Brewer.mkv" --edit info --set "title=Black Snake Moan"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Black Swan (2010) Darren Aronofsky.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Black Swan (2010) Darren Aronofsky.mkv" --edit info --set "title=Black Swan"
#
# .\mkvpropedit "F:/Data/Cinémathèque/BlacKkKlansman (2018) Spike Lee.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/BlacKkKlansman (2018) Spike Lee.mkv" --edit info --set "title=BlacKkKlansman"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blade (1998) Stephen Norrington.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blade (1998) Stephen Norrington.mkv" --edit info --set "title=Blade"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blade Runner (1982) Ridley Scott (final cut).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blade Runner (1982) Ridley Scott (final cut).mkv" --edit info --set "title=Blade Runner"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blade Runner 2049 (2017) Denis Villeneuve.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blade Runner 2049 (2017) Denis Villeneuve.mkv" --edit info --set "title=Blade Runner 2049"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Diamond (2006) Edward Zwick.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Diamond (2006) Edward Zwick.mkv" --edit info --set "title=Blood Diamond"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Machines 1 (2019) Seth Ickerman, Raphaël Hernandez, Savitri Joly-Gonfard, Carpenter Brut.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Machines 1 (2019) Seth Ickerman, Raphaël Hernandez, Savitri Joly-Gonfard, Carpenter Brut.mkv" --edit info --set "title=Blood Machines 1"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Machines 2 (2019) Seth Ickerman, Raphaël Hernandez, Savitri Joly-Gonfard, Carpenter Brut.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Machines 2 (2019) Seth Ickerman, Raphaël Hernandez, Savitri Joly-Gonfard, Carpenter Brut.mkv" --edit info --set "title=Blood Machines 2"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Machines 3 (2019) Seth Ickerman, Raphaël Hernandez, Savitri Joly-Gonfard, Carpenter Brut.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blood Machines 3 (2019) Seth Ickerman, Raphaël Hernandez, Savitri Joly-Gonfard, Carpenter Brut.mkv" --edit info --set "title=Blood Machines 3"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blow Out (1981) Brian De Palma.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blow Out (1981) Brian De Palma.mkv" --edit info --set "title=Blow Out"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blue Valentine (2010) Derek Cianfrance.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blue Valentine (2010) Derek Cianfrance.mkv" --edit info --set "title=Blue Valentine"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Blue Velvet (1986) David Lynch.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Blue Velvet (1986) David Lynch.mkv" --edit info --set "title=Blue Velvet"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Bonnie et Clyde (1967) Arthur Penn.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Bonnie et Clyde (1967) Arthur Penn.mkv" --edit info --set "title=Bonnie et Clyde"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Boogie Nights (1997) Paul Thomas Anderson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Boogie Nights (1997) Paul Thomas Anderson.mkv" --edit info --set "title=Boogie Nights"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Boogie Nights (1998) Paul Thomas Anderson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Boogie Nights (1998) Paul Thomas Anderson.mkv" --edit info --set "title=Boogie Nights"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Boulevard de la Mort (2007) Quentin Tarantino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Boulevard de la Mort (2007) Quentin Tarantino.mkv" --edit info --set "title=Boulevard de la Mort"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Boulevard du crépuscule (1950) Billy Wilder, Charles Brackett.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Boulevard du crépuscule (1950) Billy Wilder, Charles Brackett.mkv" --edit info --set "title=Boulevard du crépuscule"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Boulevard du crépuscule (1950) Billy Wilder.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Boulevard du crépuscule (1950) Billy Wilder.mkv" --edit info --set "title=Boulevard du crépuscule"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Boyhood (2014) Richard Linklater.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Boyhood (2014) Richard Linklater.mkv" --edit info --set "title=Boyhood"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Braindead (1992) Peter Jackson (uncut).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Braindead (1992) Peter Jackson (uncut).mkv" --edit info --set "title=Braindead"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Braveheart (1995) Mel Gibson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Braveheart (1995) Mel Gibson.mkv" --edit info --set "title=Braveheart"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Brazil (1985) Terry Gilliam.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Brazil (1985) Terry Gilliam.mkv" --edit info --set "title=Brazil"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Breakfast Club (1985) John Hughes.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Breakfast Club (1985) John Hughes.mkv" --edit info --set "title=Breakfast Club"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Brendan et le secret de Kells (2009) Tomm Moore, Nora Twomey [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Brendan et le secret de Kells (2009) Tomm Moore, Nora Twomey [ANIMATION].mkv" --edit info --set "title=Brendan et le secret de Kells"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Brimstone (2017) Martin Koolhoven.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Brimstone (2017) Martin Koolhoven.mkv" --edit info --set "title=Brimstone"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Brokeback Mountain (2005) Ang Lee.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Brokeback Mountain (2005) Ang Lee.mkv" --edit info --set "title=Brokeback Mountain"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Buffalo'66 (1998) Vincent Gallo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Buffalo'66 (1998) Vincent Gallo.mkv" --edit info --set "title=Buffalo'66"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Buffet Froid (1979) Bertrand Blier.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Buffet Froid (1979) Bertrand Blier.mkv" --edit info --set "title=Buffet Froid"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Burning (2018) Lee Chang-dong.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Burning (2018) Lee Chang-dong.mkv" --edit info --set "title=Burning"
#
# .\mkvpropedit "F:/Data/Cinémathèque/C'est Arrive Pres De Chez Vous (1992) Benoît Poelvoorde, Rémy Belvaux, André Bonzel.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/C'est Arrive Pres De Chez Vous (1992) Benoît Poelvoorde, Rémy Belvaux, André Bonzel.mkv" --edit info --set "title=C'est Arrive Pres De Chez Vous"
#
# .\mkvpropedit "F:/Data/Cinémathèque/C'est la vie, Le Sens de la fête (2017) Olivier Nakache, Éric Toledano.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/C'est la vie, Le Sens de la fête (2017) Olivier Nakache, Éric Toledano.mkv" --edit info --set "title=C'est la vie, Le Sens de la fête"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Calamity, une enfance de Martha Jane Cannary (2020) Rémi Chayé [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Calamity, une enfance de Martha Jane Cannary (2020) Rémi Chayé [ANIMATION].mkv" --edit info --set "title=Calamity, une enfance de Martha Jane Cannary"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Call Me by Your Name (2017) Luca Guadagnino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Call Me by Your Name (2017) Luca Guadagnino.mkv" --edit info --set "title=Call Me by Your Name"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cannibal Holocaust (1980) Ruggero Deodato.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cannibal Holocaust (1980) Ruggero Deodato.mkv" --edit info --set "title=Cannibal Holocaust"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Capharnaum (2018) Nadine Labaki.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Capharnaum (2018) Nadine Labaki.mkv" --edit info --set "title=Capharnaum"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Captain Fantastic (2016) Matt Ross.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Captain Fantastic (2016) Matt Ross.mkv" --edit info --set "title=Captain Fantastic"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Carrie au bal du Diable (1976) Brian de Palma.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Carrie au bal du Diable (1976) Brian de Palma.mkv" --edit info --set "title=Carrie au bal du Diable"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Casablanca (1942) Michael Curtiz.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Casablanca (1942) Michael Curtiz.mkv" --edit info --set "title=Casablanca"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cashback (2006) Sean Ellis.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cashback (2006) Sean Ellis.mkv" --edit info --set "title=Cashback"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Casino (1995) Martin Scorsese.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Casino (1995) Martin Scorsese.mkv" --edit info --set "title=Casino"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Casino Royale (2006) Martin Campbell (Extended).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Casino Royale (2006) Martin Campbell (Extended).mkv" --edit info --set "title=Casino Royale"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Casque d'or (1952) Jacques Becker.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Casque d'or (1952) Jacques Becker.mkv" --edit info --set "title=Casque d'or"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Catch Me If You Can (2002) Steven Spielberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Catch Me If You Can (2002) Steven Spielberg.mkv" --edit info --set "title=Catch Me If You Can"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Certains l'aiment chaud (1959) Billy Wilder.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Certains l'aiment chaud (1959) Billy Wilder.mkv" --edit info --set "title=Certains l'aiment chaud"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chantons Sous La Pluie (1952) Gene Kelly, Stanley Donen.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chantons Sous La Pluie (1952) Gene Kelly, Stanley Donen.mkv" --edit info --set "title=Chantons Sous La Pluie"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chappie (2015) Neill Blomkamp.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chappie (2015) Neill Blomkamp.mkv" --edit info --set "title=Chappie"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chicago (2002) Rob Marshall.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chicago (2002) Rob Marshall.mkv" --edit info --set "title=Chicago"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chinatown (1974) Roman Polanski.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chinatown (1974) Roman Polanski.mkv" --edit info --set "title=Chinatown"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Christine (1984) John Carpenter.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Christine (1984) John Carpenter.mkv" --edit info --set "title=Christine"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chromosome 3 (1979) David Cronenberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chromosome 3 (1979) David Cronenberg.mkv" --edit info --set "title=Chromosome 3"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chronicle (2012) Josh Trank [DIRECTOR].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chronicle (2012) Josh Trank [DIRECTOR].mkv" --edit info --set "title=Chronicle"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chungking Express (1995) Wong Kar-wai.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chungking Express (1995) Wong Kar-wai.mkv" --edit info --set "title=Chungking Express"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Chérie, j'ai rétréci les gosses (1989) Joe Johnston.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Chérie, j'ai rétréci les gosses (1989) Joe Johnston.mkv" --edit info --set "title=Chérie, j'ai rétréci les gosses"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cinema Paradiso (1988) Cinema.Paradiso.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cinema Paradiso (1988) Cinema.Paradiso.mkv" --edit info --set "title=Cinema Paradiso"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cinema Paradiso (1988) Giuseppe Tornatore [version longue].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cinema Paradiso (1988) Giuseppe Tornatore [version longue].mkv" --edit info --set "title=Cinema Paradiso"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Citizen Kane (1941) Orson Welles.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Citizen Kane (1941) Orson Welles.mkv" --edit info --set "title=Citizen Kane"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cloud Atlas (2013) Lana Wachowski, Lilly Wachowski, Tom Tykwer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cloud Atlas (2013) Lana Wachowski, Lilly Wachowski, Tom Tykwer.mkv" --edit info --set "title=Cloud Atlas"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cloud Atlas (2013) Tom Tykwer, Lana Wachowski, Lilly Wachowski.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cloud Atlas (2013) Tom Tykwer, Lana Wachowski, Lilly Wachowski.mkv" --edit info --set "title=Cloud Atlas"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cloverfield (2008) Matt Reeves.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cloverfield (2008) Matt Reeves.mkv" --edit info --set "title=Cloverfield"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cold Fish (2010) Sion Sono.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cold Fish (2010) Sion Sono.mkv" --edit info --set "title=Cold Fish"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cold War (2018) Paweł Pawlikowski.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cold War (2018) Paweł Pawlikowski.mkv" --edit info --set "title=Cold War"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Collateral (2004) Michael Mann.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Collateral (2004) Michael Mann.mkv" --edit info --set "title=Collateral"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Colossal (2016) Nacho Vigalondo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Colossal (2016) Nacho Vigalondo.mkv" --edit info --set "title=Colossal"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Come True (2021) Anthony Scott Burns.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Come True (2021) Anthony Scott Burns.mkv" --edit info --set "title=Come True"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Coming Home (2014) Zhang Yimou.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Coming Home (2014) Zhang Yimou.mkv" --edit info --set "title=Coming Home"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Confessions (2010) Tetsuya Nakashima.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Confessions (2010) Tetsuya Nakashima.mkv" --edit info --set "title=Confessions"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Contact (1997) Robert Zemeckis.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Contact (1997) Robert Zemeckis.mkv" --edit info --set "title=Contact"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Conte des chrysanthemes tardifs 1939 VOSTF DVDRIP HEVC AZAZE.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Conte des chrysanthemes tardifs 1939 VOSTF DVDRIP HEVC AZAZE.mkv" --edit info --set "title=Conte des chrysanthemes tardifs 1939 VOSTF DVDRIP HEVC AZAZE"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Coup de foudre à Notting Hill (1999) Roger Michell.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Coup de foudre à Notting Hill (1999) Roger Michell.mkv" --edit info --set "title=Coup de foudre à Notting Hill"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Crank, Hyper Tension (2006) Mark Neveldine, Brian Taylor.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Crank, Hyper Tension (2006) Mark Neveldine, Brian Taylor.mkv" --edit info --set "title=Crank, Hyper Tension"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Crash (1996) David Cronenberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Crash (1996) David Cronenberg.mkv" --edit info --set "title=Crash"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Creed, L'Héritage de Rocky Balboa (2015) Ryan Coogler.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Creed, L'Héritage de Rocky Balboa (2015) Ryan Coogler.mkv" --edit info --set "title=Creed, L'Héritage de Rocky Balboa"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Crimson Peak (2015) Guillermo del Toro.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Crimson Peak (2015) Guillermo del Toro.mkv" --edit info --set "title=Crimson Peak"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cris et chuchotements (1972).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cris et chuchotements (1972).mkv" --edit info --set "title=Cris et chuchotements"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Crows Zero (2007) Takashi Miike.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Crows Zero (2007) Takashi Miike.mkv" --edit info --set "title=Crows Zero"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Crows Zero 2 (2009) Takashi Miike.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Crows Zero 2 (2009) Takashi Miike.mkv" --edit info --set "title=Crows Zero 2"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Crépuscule à Tokyo (1957) Yasujirō Ozu.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Crépuscule à Tokyo (1957) Yasujirō Ozu.mkv" --edit info --set "title=Crépuscule à Tokyo"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cure (1997) Kiyoshi Kurosawa.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cure (1997) Kiyoshi Kurosawa.mkv" --edit info --set "title=Cure"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Cyrano de Bergerac (1990) Jean-Paul Rappeneau.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Cyrano de Bergerac (1990) Jean-Paul Rappeneau.mkv" --edit info --set "title=Cyrano de Bergerac"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dallas Buyers Club (2013) Jean-Marc Vallée.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dallas Buyers Club (2013) Jean-Marc Vallée.mkv" --edit info --set "title=Dallas Buyers Club"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dancer in the Dark (2000) Lars von Trier.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dancer in the Dark (2000) Lars von Trier.mkv" --edit info --set "title=Dancer in the Dark"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dans la brume (2018) Daniel Roby.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dans la brume (2018) Daniel Roby.mkv" --edit info --set "title=Dans la brume"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dans un jardin qu'on dirait éternel  (2020) Tatsushi Ōmori.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dans un jardin qu'on dirait éternel  (2020) Tatsushi Ōmori.mkv" --edit info --set "title=Dans un jardin qu'on dirait éternel "
#
# .\mkvpropedit "F:/Data/Cinémathèque/Danse avec les loups  (1990) Kevin Costner [LONGUE].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Danse avec les loups  (1990) Kevin Costner [LONGUE].mkv" --edit info --set "title=Danse avec les loups "
#
# .\mkvpropedit "F:/Data/Cinémathèque/Danse avec les loups (1990) Kevin Costner [LONGUE].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Danse avec les loups (1990) Kevin Costner [LONGUE].mkv" --edit info --set "title=Danse avec les loups"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Danse avec les Loups (1990) Kevin Costner.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Danse avec les Loups (1990) Kevin Costner.mkv" --edit info --set "title=Danse avec les Loups"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dark City (1998) Alex Proyas.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dark City (1998) Alex Proyas.mkv" --edit info --set "title=Dark City"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dark Crystal (1982) Jim Henson, Frank Oz.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dark Crystal (1982) Jim Henson, Frank Oz.mkv" --edit info --set "title=Dark Crystal"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dark Waters (2019) Todd Haynes.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dark Waters (2019) Todd Haynes.mkv" --edit info --set "title=Dark Waters"
#
# .\mkvpropedit "F:/Data/Cinémathèque/De l'eau tiède sous un pont rouge (2001) Shôhei Imamura.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/De l'eau tiède sous un pont rouge (2001) Shôhei Imamura.mkv" --edit info --set "title=De l'eau tiède sous un pont rouge"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dead Man (1995) Jim Jarmusch.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dead Man (1995) Jim Jarmusch.mkv" --edit info --set "title=Dead Man"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Delicatessen (1991) Jean-Pierre Jeunet.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Delicatessen (1991) Jean-Pierre Jeunet.mkv" --edit info --set "title=Delicatessen"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Delivrance (1972) John Boorman.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Delivrance (1972) John Boorman.mkv" --edit info --set "title=Delivrance"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Departures (2008) Yōjirō Takita.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Departures (2008) Yōjirō Takita.mkv" --edit info --set "title=Departures"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dernier train pour Busan (2016) Sang-ho Yeon.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dernier train pour Busan (2016) Sang-ho Yeon.mkv" --edit info --set "title=Dernier train pour Busan"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Des hommes d'honneur (1992) Rob Reiner.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Des hommes d'honneur (1992) Rob Reiner.mkv" --edit info --set "title=Des hommes d'honneur"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Detective Dee III, La légende des rois célestes (2018) Tsui Hark.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Detective Dee III, La légende des rois célestes (2018) Tsui Hark.mkv" --edit info --set "title=Detective Dee III, La légende des rois célestes"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Detective Dee, Le mystère de la flamme fantôme (2010) Tsui Hark.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Detective Dee, Le mystère de la flamme fantôme (2010) Tsui Hark.mkv" --edit info --set "title=Detective Dee, Le mystère de la flamme fantôme"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Detroit (2017) Kathryn Bigelow.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Detroit (2017) Kathryn Bigelow.mkv" --edit info --set "title=Detroit"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 1, Piege De Cristal (1988) John McTiernan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 1, Piege De Cristal (1988) John McTiernan.mkv" --edit info --set "title=Die Hard 1, Piege De Cristal"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 3 - Une journée en enfer (1995) John McTiernan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 3 - Une journée en enfer (1995) John McTiernan.mkv" --edit info --set "title=Die Hard 3 - Une journée en enfer"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 3 Une Journee En Enfer (1995) John McTiernan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 3 Une Journee En Enfer (1995) John McTiernan.mkv" --edit info --set "title=Die Hard 3 Une Journee En Enfer"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 4, Retour en Enfer (2007) Len Wiseman.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Die Hard 4, Retour en Enfer (2007) Len Wiseman.mkv" --edit info --set "title=Die Hard 4, Retour en Enfer"
#
# .\mkvpropedit "F:/Data/Cinémathèque/District 9 (2009) Neill Blomkamp.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/District 9 (2009) Neill Blomkamp.mkv" --edit info --set "title=District 9"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Django Unchained (2012) Quentin Tarantino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Django Unchained (2012) Quentin Tarantino.mkv" --edit info --set "title=Django Unchained"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Docteur Folamour (1964) Stanley Kubrick.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Docteur Folamour (1964) Stanley Kubrick.mkv" --edit info --set "title=Docteur Folamour"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dogs Don’t Wear Pants (2019) Jukka-Pekka Valkeapää.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dogs Don’t Wear Pants (2019) Jukka-Pekka Valkeapää.mkv" --edit info --set "title=Dogs Don’t Wear Pants"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Donnie Darko (2001) Richard Kelly.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Donnie Darko (2001) Richard Kelly.mkv" --edit info --set "title=Donnie Darko"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dossier secret (1955) Orson Welles.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dossier secret (1955) Orson Welles.mkv" --edit info --set "title=Dossier secret"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Douleur et Gloire (2019) Pedro Almodovar.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Douleur et Gloire (2019) Pedro Almodovar.mkv" --edit info --set "title=Douleur et Gloire"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dracula (1931) Tod Browning, Karl Freund.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dracula (1931) Tod Browning, Karl Freund.mkv" --edit info --set "title=Dracula"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dracula (1931) Tod Browning.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dracula (1931) Tod Browning.mkv" --edit info --set "title=Dracula"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dracula (1992) Francis-Ford Coppola.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dracula (1992) Francis-Ford Coppola.mkv" --edit info --set "title=Dracula"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dragons 1 (2010) Dean DeBlois, Chris Sanders.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dragons 1 (2010) Dean DeBlois, Chris Sanders.mkv" --edit info --set "title=Dragons 1"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Drive (2011) Nicolas Winding Refn.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Drive (2011) Nicolas Winding Refn.mkv" --edit info --set "title=Drive"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Drunk (2020) Thomas Vinterberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Drunk (2020) Thomas Vinterberg.mkv" --edit info --set "title=Drunk"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Duel (1971) Steven Spielberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Duel (1971) Steven Spielberg.mkv" --edit info --set "title=Duel"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Duel au soleil (1946) King Vidor, Otto Brower.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Duel au soleil (1946) King Vidor, Otto Brower.mkv" --edit info --set "title=Duel au soleil"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Dunkerque (2017) Christopher Nolan [4K].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Dunkerque (2017) Christopher Nolan [4K].mkv" --edit info --set "title=Dunkerque"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Déjà Vu (2006) Tony Scott.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Déjà Vu (2006) Tony Scott.mkv" --edit info --set "title=Déjà Vu"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Démineurs (2009) Kathryn Bigelow.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Démineurs (2009) Kathryn Bigelow.mkv" --edit info --set "title=Démineurs"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Détective Dee II,  La Légende du Dragon des Mers (2013) Tsui Hark.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Détective Dee II,  La Légende du Dragon des Mers (2013) Tsui Hark.mkv" --edit info --set "title=Détective Dee II,  La Légende du Dragon des Mers"
#
# .\mkvpropedit "F:/Data/Cinémathèque/E.T. the Extra-Terrestrial (1982) Steven Spielberg.mkv" --tags all:
# ...
# .\mkvpropedit "F:/Data/Cinémathèque/Toy Story (1995) John Lasseter.mkv" --edit info --set "title=Toy Story"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Toy Story 3 (2010) Lee Unkrich.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Toy Story 3 (2010) Lee Unkrich.mkv" --edit info --set "title=Toy Story 3"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Toy Story 4 (2019) Josh Cooley.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Toy Story 4 (2019) Josh Cooley.mkv" --edit info --set "title=Toy Story 4"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Training Day (2001) Antoine Fuqua.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Training Day (2001) Antoine Fuqua.mkv" --edit info --set "title=Training Day"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Troie (2014) Wolfgang Petersen (Director's Cut).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Troie (2014) Wolfgang Petersen (Director's Cut).mkv" --edit info --set "title=Troie"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Tron Legacy (2010) Joseph Kosinski.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Tron Legacy (2010) Joseph Kosinski.mkv" --edit info --set "title=Tron Legacy"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Tropical Malady (2004) Apichatpong Weerasethakul.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Tropical Malady (2004) Apichatpong Weerasethakul.mkv" --edit info --set "title=Tropical Malady"
#
# .\mkvpropedit "F:/Data/Cinémathèque/True Grit (2010) Ethan Coen, Joel Coen.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/True Grit (2010) Ethan Coen, Joel Coen.mkv" --edit info --set "title=True Grit"
#
# .\mkvpropedit "F:/Data/Cinémathèque/True Romance (1993) Tony Scott [DIRECTOR].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/True Romance (1993) Tony Scott [DIRECTOR].mkv" --edit info --set "title=True Romance"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Tu ne tueras point (2016) Mel Gibson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Tu ne tueras point (2016) Mel Gibson.mkv" --edit info --set "title=Tu ne tueras point"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Twin Peaks fire walk with me (1992) David Lynch.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Twin Peaks fire walk with me (1992) David Lynch.mkv" --edit info --set "title=Twin Peaks fire walk with me"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Two Lovers (2008) James Gray.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Two Lovers (2008) James Gray.mkv" --edit info --set "title=Two Lovers"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Un après-midi de chien (1975) Sidney Lumet.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Un après-midi de chien (1975) Sidney Lumet.mkv" --edit info --set "title=Un après-midi de chien"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Un grand voyage vers la nuit (2019) Bi Gan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Un grand voyage vers la nuit (2019) Bi Gan.mkv" --edit info --set "title=Un grand voyage vers la nuit"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Un Jour sans Fin (1993) Harold Ramis.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Un Jour sans Fin (1993) Harold Ramis.mkv" --edit info --set "title=Un Jour sans Fin"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Un monstre à Paris (2011) Bibo Bergeron [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Un monstre à Paris (2011) Bibo Bergeron [ANIMATION].mkv" --edit info --set "title=Un monstre à Paris"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Un prophète (2009) Jacques Audiard.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Un prophète (2009) Jacques Audiard.mkv" --edit info --set "title=Un prophète"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Un singe en hiver (1962) Henri Verneuil.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Un singe en hiver (1962) Henri Verneuil.mkv" --edit info --set "title=Un singe en hiver"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Under the Silver Lake (2018) David Robert Mitchell.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Under the Silver Lake (2018) David Robert Mitchell.mkv" --edit info --set "title=Under the Silver Lake"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Under the Skin (2013) Jonathan Glazer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Under the Skin (2013) Jonathan Glazer.mkv" --edit info --set "title=Under the Skin"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une Affaire de Famille (2018) Hirokazu Kore-eda.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une Affaire de Famille (2018) Hirokazu Kore-eda.mkv" --edit info --set "title=Une Affaire de Famille"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une belle journée d'été (1991) Edward Yang.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une belle journée d'été (1991) Edward Yang.mkv" --edit info --set "title=Une belle journée d'été"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une femme dans la tourmente (1964) Mikio Naruse.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une femme dans la tourmente (1964) Mikio Naruse.mkv" --edit info --set "title=Une femme dans la tourmente"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une femme sous influence (1974) John Cassavetes.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une femme sous influence (1974) John Cassavetes.mkv" --edit info --set "title=Une femme sous influence"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une Séparation (2011) Asghar Farhadi.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une Séparation (2011) Asghar Farhadi.mkv" --edit info --set "title=Une Séparation"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie de chat (2010)  Alain Gagnol, Jean-Loup Felicioli.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie de chat (2010)  Alain Gagnol, Jean-Loup Felicioli.mkv" --edit info --set "title=Une vie de chat"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie entre deux océans (2016) Derek Cianfrance.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie entre deux océans (2016) Derek Cianfrance.mkv" --edit info --set "title=Une vie entre deux océans"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie toute neuve (2008) Ounie Lecomte.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie toute neuve (2008) Ounie Lecomte.mkv" --edit info --set "title=Une vie toute neuve"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie toute neuve bonus (2008) Ounie Lecomte.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Une vie toute neuve bonus (2008) Ounie Lecomte.mkv" --edit info --set "title=Une vie toute neuve bonus"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Upside Down (2012) Juan Solanas.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Upside Down (2012) Juan Solanas.mkv" --edit info --set "title=Upside Down"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Us (2019) Jordan Peele.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Us (2019) Jordan Peele.mkv" --edit info --set "title=Us"
#
# .\mkvpropedit "F:/Data/Cinémathèque/V pour Vendetta (2006) James McTeigue.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/V pour Vendetta (2006) James McTeigue.mkv" --edit info --set "title=V pour Vendetta"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Vice (2019) Adam McKay.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Vice (2019) Adam McKay.mkv" --edit info --set "title=Vice"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Vice Versa (2015) Pete Docter.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Vice Versa (2015) Pete Docter.mkv" --edit info --set "title=Vice Versa"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Victoria (2015) Sebastian Schipper.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Victoria (2015) Sebastian Schipper.mkv" --edit info --set "title=Victoria"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Videodrome (1983) David Cronenberg.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Videodrome (1983) David Cronenberg.mkv" --edit info --set "title=Videodrome"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Virgin Suicides (1999) Sofia Coppola.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Virgin Suicides (1999) Sofia Coppola.mkv" --edit info --set "title=Virgin Suicides"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Vol au-dessus d'un nid de coucou (1976) Miloš Forman.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Vol au-dessus d'un nid de coucou (1976) Miloš Forman.mkv" --edit info --set "title=Vol au-dessus d'un nid de coucou"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Volver (2005) Pedro Almodóvar.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Volver (2005) Pedro Almodóvar.mkv" --edit info --set "title=Volver"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage au bout de l'enfer (1978) Michael Cimino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage au bout de l'enfer (1978) Michael Cimino.mkv" --edit info --set "title=Voyage au bout de l'enfer"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage of Time (2016) Terrence Malick.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage of Time (2016) Terrence Malick.mkv" --edit info --set "title=Voyage of Time"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage vers la Lune (2020) Glen Keane [ANIMATION].mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage vers la Lune (2020) Glen Keane [ANIMATION].mkv" --edit info --set "title=Voyage vers la Lune"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage à Tokyo (1953) Yasujirō Ozu.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Voyage à Tokyo (1953) Yasujirō Ozu.mkv" --edit info --set "title=Voyage à Tokyo"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Walkyrie (2008) Bryan Singer.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Walkyrie (2008) Bryan Singer.mkv" --edit info --set "title=Walkyrie"
#
# .\mkvpropedit "F:/Data/Cinémathèque/WALL-E (2008) Andrew Stanton.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/WALL-E (2008) Andrew Stanton.mkv" --edit info --set "title=WALL-E"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Wallace et Gromit, le Mystère du lapin-garou (2005) Nick Park, Steve Box.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Wallace et Gromit, le Mystère du lapin-garou (2005) Nick Park, Steve Box.mkv" --edit info --set "title=Wallace et Gromit, le Mystère du lapin-garou"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Warm Bodies (2013) Jonathan Levine.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Warm Bodies (2013) Jonathan Levine.mkv" --edit info --set "title=Warm Bodies"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Watchmen (2009) Zack Snyder (Ultimate Cut).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Watchmen (2009) Zack Snyder (Ultimate Cut).mkv" --edit info --set "title=Watchmen"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Waterworld (1995) Kevin Reynolds.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Waterworld (1995) Kevin Reynolds.mkv" --edit info --set "title=Waterworld"
#
# .\mkvpropedit "F:/Data/Cinémathèque/We Need to Talk about Kevin (2011) Lynne Ramsay.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/We Need to Talk about Kevin (2011) Lynne Ramsay.mkv" --edit info --set "title=We Need to Talk about Kevin"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Welcome to Dongmakgol (2005) Park Kwang-hyun.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Welcome to Dongmakgol (2005) Park Kwang-hyun.mkv" --edit info --set "title=Welcome to Dongmakgol"
#
# .\mkvpropedit "F:/Data/Cinémathèque/West Side Story (1961) Jerome Robbins, Robert Wise.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/West Side Story (1961) Jerome Robbins, Robert Wise.mkv" --edit info --set "title=West Side Story"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Whiplash (2014) Damien Chazelle.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Whiplash (2014) Damien Chazelle.mkv" --edit info --set "title=Whiplash"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Why Don't You Play in Hell (2013) Sion Sono.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Why Don't You Play in Hell (2013) Sion Sono.mkv" --edit info --set "title=Why Don't You Play in Hell"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Will Hunting (1997) Gus Van Sant.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Will Hunting (1997) Gus Van Sant.mkv" --edit info --set "title=Will Hunting"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Willow (1988) Ron Howard (Remastered).mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Willow (1988) Ron Howard (Remastered).mkv" --edit info --set "title=Willow"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Wind River (2017) Taylor Sheridan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Wind River (2017) Taylor Sheridan.mkv" --edit info --set "title=Wind River"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Winter sleep (2014) Nuri Bilge Ceylan.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Winter sleep (2014) Nuri Bilge Ceylan.mkv" --edit info --set "title=Winter sleep"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Woman at War (2018) Benedikt Erlingsson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Woman at War (2018) Benedikt Erlingsson.mkv" --edit info --set "title=Woman at War"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Wonder (2017) Stephen Chbosky.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Wonder (2017) Stephen Chbosky.mkv" --edit info --set "title=Wonder"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Wonder Woman (2017) Patty Jenkins.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Wonder Woman (2017) Patty Jenkins.mkv" --edit info --set "title=Wonder Woman"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Yi Yi (2000) Edward Yang.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Yi Yi (2000) Edward Yang.mkv" --edit info --set "title=Yi Yi"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Yojimbo (1961) Akira Kurosawa.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Yojimbo (1961) Akira Kurosawa.mkv" --edit info --set "title=Yojimbo"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Young Ones (2014) Jake Paltrow.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Young Ones (2014) Jake Paltrow.mkv" --edit info --set "title=Young Ones"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Your Name. (2016) Makoto Shinkai.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Your Name. (2016) Makoto Shinkai.mkv" --edit info --set "title=Your Name."
#
# .\mkvpropedit "F:/Data/Cinémathèque/Youth (2015) Paolo Sorrentino.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Youth (2015) Paolo Sorrentino.mkv" --edit info --set "title=Youth"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Zabriskie Point (1970) Michelangelo Antonioni.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Zabriskie Point (1970) Michelangelo Antonioni.mkv" --edit info --set "title=Zabriskie Point"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Zardoz (1974) John Boorman.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Zardoz (1974) John Boorman.mkv" --edit info --set "title=Zardoz"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Zero Dark Thirty (2012) Kathryn Bigelow.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Zero Dark Thirty (2012) Kathryn Bigelow.mkv" --edit info --set "title=Zero Dark Thirty"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Zodiac (2007) David Fincher.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Zodiac (2007) David Fincher.mkv" --edit info --set "title=Zodiac"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Zombie (1978) George A. Romero.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Zombie (1978) George A. Romero.mkv" --edit info --set "title=Zombie"
#
# .\mkvpropedit "F:/Data/Cinémathèque/Zootopia (2016) Rich Moore, Byron Howard, Jared Bush.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/Zootopia (2016) Rich Moore, Byron Howard, Jared Bush.mkv" --edit info --set "title=Zootopia"
#
# .\mkvpropedit "F:/Data/Cinémathèque/À Bord du Darjeeling Limited (2007) Wes Anderson.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/À Bord du Darjeeling Limited (2007) Wes Anderson.mkv" --edit info --set "title=À Bord du Darjeeling Limited"
#
# .\mkvpropedit "F:/Data/Cinémathèque/À bout de souffle (1960) Jean-Luc Godard.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/À bout de souffle (1960) Jean-Luc Godard.mkv" --edit info --set "title=À bout de souffle"
#
# .\mkvpropedit "F:/Data/Cinémathèque/À toute épreuve (1992) John Woo.mkv" --tags all:
# .\mkvpropedit "F:/Data/Cinémathèque/À toute épreuve (1992) John Woo.mkv" --edit info --set "title=À toute épreuve"

# %%
# Out:
# "{'date': '1992', 'directors': ['John Woo']}"

# %% [markdown]
# ---

# %% [markdown]
# Thibault **Santonja**
# 2021
